# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "BoyanMihaylov"

# %% [markdown]
# # Agent Based Modeling - Mesa
#
# "[Mesa](https://mesa.readthedocs.io/en/stable/index.html) is an agent-based modeling framework in Python. Mesa allows users to quickly create agent-based models using built-in core components (such as spatial grids and agent schedulers) or customized implementations, visualize them using a browser-based interface, and analyze their results using Python’s data analysis tools."
#
# _This notebook is based on and uses parts of texts from the Mesa docs._
#
# ### Discretised Lotka Volterra
# In this notebook we aim to familiarise you with Mesa and its Object Oriented Programming approach to agent-based models. This will be done through implementation of a simplified preditor-prey model (discretised Lotka Volterra).
#
# If you are not yet comfortable with Object Oriented Programming or need a refresher, please visit [this page](https://python.swaroopch.com/oop.html).
#
# We will create a version of the "sheep-wolf" model wherein wolves and sheep wander randomly around the landscape. To allow the population to grow, each wolf or sheep has a fixed probability of reproducing at each timestep. In this simplified version, sheep do not have to eat, and only die when eaten by a wolf. Wolves, however, have a probability of dying. This produces interesting population dynamics, but creates a model that is ultimately unstable.
#
# To do this we need the following:
# - **Agents:** the predators and preys
# - **Environment:** an area in which the predators and prey can move around and interact
# - **Model:** the controller that links the environment and the agents
#
# We've already implemented the model and the environment is already implemented by Mesa, but it is up to you to implement the Agents!

# %%
from IPython.display import clear_output
import mesa
#import ipynb
clear_output(wait=True)
print("Everything imported!")
# Out:
# Everything imported!

# %% [markdown]
# ### Testing
# Since testing each of the methods that you will create seperately might be difficult, we provide you with a very minimal model that will be used during the testing phase. Later in this notebook we will introduce you to the model that has been implemented in `model.py`.

# %%
from mesa import Model
from mesa.space import MultiGrid

class TestModel(Model):
    def __init__(self, width, height):
        self.height = width
        self.width = height
        
        self.grid = MultiGrid(self.width, self.height, torus=True)
        
        self.n_agents = 0
        self.agents = []

    
    def new_agent(self, agent_type, pos):
        '''
        Method that enables us to add agents of a given type.
        '''
        self.n_agents += 1
        
        # Create a new agent of the given type
        new_agent = agent_type(self.n_agents, self, pos)
        
        # Place the agent on the grid
        self.grid.place_agent(new_agent, pos)
        
        # And add the agent to the model so we can track it
        self.agents.append(new_agent)
        
    def remove_agent(self, agent):
        '''
        Method that enables us to remove passed agents.
        '''
        self.n_agents -= 1
        
        # Remove agent from grid
        self.grid.remove_agent(agent)
        
        # Remove agent from model
        self.agents.remove(agent)
        
    def step(self):
        '''
        Method that steps every agent. 
        
        Prevents applying step on new agents by creating a local list.
        '''
        for agent in list(self.agents):
            agent.step()

# %% [markdown]
# ### Agents - Random walker
# As both the sheep and the wolves will walk around randomly, we will first implement a `RandomWalker` class. We can then re-use (inherit) this class when making our `Wolf` and `Sheep` classes. Below you can find the framework for the class, but you will have to implement the `random_move()` method. This method should get the neighbouring cells (Moore's neighbourhood), select one, and move the agent to this cell.
#
# Find the following functions through the provided link and find out which inputs they need:
#  - [`MultiGrid.get_neighborhood()`](https://mesa.readthedocs.io/en/stable/mesa.html#mesa.space.NetworkGrid.get_neighborhood)
#  - [`MultiGrid.move_agent()`](https://mesa.readthedocs.io/en/stable/mesa.html#mesa.space.NetworkGrid.move_agent)
#
# Keep in mind that the `model` that is passed when the RandomWalker is initialised contains the grid. It is accessable through `self.model.grid` in the `random_move` function.

# %%
from mesa import Agent
import random

class RandomWalker(Agent):
    def __init__(self, unique_id, model, pos):
        super().__init__(unique_id, model)

        self.pos = pos

    def random_move(self):
        ''' 
        This method should get the neighbouring cells (Moore's neighbourhood), select one, and move the agent to this cell.
        '''
        
        nbrhood = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
        
        if len(nbrhood):
            target = random.choice(nbrhood)
            self.model.grid.move_agent(self, target)

# %%
tester = TestModel(10, 10)

# Create a RandomWalker, so that we can call the random_move() method
start_position = (5, 5)
tester.new_agent(RandomWalker, start_position)

# Create a reference, so that we can properly test
walker = tester.agents[0]

# Check movement
walker.random_move()
assert walker.pos != (5, 5), "The walker has not moved!"
assert abs(walker.pos[0] - 5) <= 1 and abs(walker.pos[1] - 5) <= 1, "The walker has moved more than 1 square"
# Out:
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:12: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.agents = []
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\803836949.py:6: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)

# %% [markdown]
# ### Agents - Sheep
# As described above, to allow the population to grow, each wolf or sheep has a fixed probability of reproducing at each timestep. Sheep do not have to eat, and only die when eaten by a wolf. We have again provided you with the framework for this class, but you will have to implement the `step()` method. This method should move the Sheep using the `random_move()` method implemented earlier, then conditionally reproduce. You can use the 'new_agent()' method implemented in model to create new sheep.
#
# Attributes/methods you might need:
#  - `self.random_move()`
#  - `self.model.new_agent()`
#  - `self.model.sheep_reproduction_chance`

# %%
class Sheep(RandomWalker):
    def __init__(self, unique_id, model, pos):
        super().__init__(unique_id, model, pos)

    def step(self):
        '''
        This method should move the Sheep using the `random_move()` method implemented earlier, then conditionally reproduce.
        '''
        
        # Move
        self.random_move()
        
        # Reproduce
        if random.random() < self.model.sheep_reproduction_chance:
            self.model.new_agent(Sheep, self.pos)

# %%
tester = TestModel(10, 10)
tester.sheep_reproduction_chance = 1

# Create a Sheep 
start_position = (5, 5)
tester.new_agent(Sheep, start_position)

# Create a reference, so that we can properly test
sheep = tester.agents[0]

# Check movement
tester.step()
assert sheep.pos != (5, 5), "The sheep has not moved!"
assert abs(sheep.pos[0] - 5) <= 1 and abs(sheep.pos[1] - 5) <= 1, "The sheep has moved more than 1 square!"

# Check fertility
assert tester.n_agents == 2, "Your sheep is infertile!"
tester.sheep_reproduction_chance = 0
tester.step()
assert tester.n_agents == 2, "Your sheep are too fertile!"

# Check if the random_move function was used
old_pos = sheep.pos
sheep.random_move = lambda: False
tester.step()
assert old_pos == sheep.pos, "You didn't use the random_move() function!"
# Out:
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:12: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.agents = []
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\803836949.py:6: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)

# %% [markdown]
# ### Agents - Wolf
# Each wolf has a fixed probability of dying at each timestep. When wolves meet a sheep they will eat it and then reproduce. We have again provided you with the framework for this class, but you will have to implement the step() method. This method should move the wolf, then check for sheep on its location, eat the sheep if it is there and reproduce, and finally conditionally die.
#
#
# Attributes/methods you might need:
#  - `self.random_move()`
#  - `self.model.new_agent()`
#  - `self.model.remove_agent()`
#  - `self.model.wolf_death_chance`
#  - [`MultiGrid.get_neighbors()`](https://github.com/projectmesa/mesa/blob/master/mesa/space.py)

# %%
class Wolf(RandomWalker):
    def __init__(self, unique_id, model, pos):
        super().__init__(unique_id, model, pos)

        self.eaten_sheep = 0

    def step(self):
        '''
        This method should move the wolf, then check for sheep on its location, 
        eat one sheep if it is available and reproduce, and finally, conditionally die.
        '''
        
        self.random_move()

        # Get sheep neighbours
        nbrs = self.model.grid.get_neighbors(self.pos, moore=True, include_center=True)
        sheep_nbrs = [nbr for nbr in nbrs if isinstance(nbr, Sheep)]

        # Eat sheep and reproduce
        if len(sheep_nbrs) > 0:
            self.model.remove_agent(random.choice(sheep_nbrs))
            self.model.new_agent(Wolf, self.pos)

            # Log eaten sheep
            self.eaten_sheep += 1

        # Die
        if random.random() < self.model.wolf_death_chance:
            self.model.remove_agent(self)

# %%
tester = TestModel(10, 10)
tester.wolf_death_chance = 0

# Create a Wolf 
start_position = (5, 5)
tester.new_agent(Wolf, start_position)

# Create a reference, so that we can properly test
wolf = tester.agents[0]

# Check movement
tester.step()
assert wolf.pos != (5, 5), "The wolf has not moved!"
assert abs(wolf.pos[0] - 5) <= 1 and abs(wolf.pos[1] - 5) <= 1, "The wolf has moved more than 1 square!"

# Check death rates
assert tester.n_agents == 1, "Your wolf died!"
tester.wolf_death_chance = 1
tester.step()
assert tester.n_agents == 0, "Your wolf is invincible!"

# Create another model so that we can be sure the wolf eats the sheep
tester = TestModel(1, 1)
tester.wolf_death_chance = 0
tester.sheep_reproduction_chance = 0

# Create a Sheep and a Wolf
start_position = (0, 0)
tester.new_agent(Sheep, start_position)
tester.new_agent(Wolf, start_position)

# Check if the sheep was eaten
tester.step()
assert type(tester.agents[0]) is not Sheep, "The sheep has not been eaten!"
# Out:
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:12: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.agents = []
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\803836949.py:6: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\293147639.py:25: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_agent, pos)

# %% [markdown]
# ### The model
# Now that you have implemented the agents, we will introduce you to the model. The model links the agents to the environment and provides methods that make interactions with the model easy. It uses the `DataCollector` class, which we will explain later, and the `RandomActivation` class. The `RandomActivation` class is a scheduler that iterates through each of the agents randomly and uses its `step()` method. We have seperated the Sheep scheduler from the Wolf scheduler to prevent what is called a ["race-condition"](https://en.wikipedia.org/wiki/Race_condition) wherein a Sheep gets eaten before it is its turn to `step()`.
#
# At the time of writing of this notebook, there are 4 different schedulers available in Mesa:
# - `BaseScheduler`: This is a scheduler that activates agents one at a time, in the order they were added.
# - `RandomActivation`: Activates each agent once per step, in random order, with the order reshuffled every step.
# - `SimultaneousActivation`: Activates all agents simultaneously.
# - `StagedActivation`: Allows agent activation to be divided into several stages instead of a single `step` method.
#
# Check out [the docs](https://mesa.readthedocs.io/en/stable/tutorials/intro_tutorial.html#adding-the-scheduler) to learn more.

# %%
import random

from mesa import Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
from mesa.time import RandomActivation

class WolfSheep(Model):
    '''
    Wolf-Sheep Predation Model
    '''
    
    def __init__(self, height=20, width=20,
                 initial_sheep=100, initial_wolves=30,
                 sheep_reproduction_chance=0.05, wolf_death_chance=0.05):

        super().__init__()

        self.height = height
        self.width = width
        self.initial_sheep = initial_sheep
        self.initial_wolves = initial_wolves
        self.sheep_reproduction_chance = sheep_reproduction_chance
        self.wolf_death_chance = wolf_death_chance

        # Add a schedule for sheep and wolves seperately to prevent race-conditions
        self.schedule_Sheep = RandomActivation(self)
        self.schedule_Wolf = RandomActivation(self)

        self.grid = MultiGrid(self.width, self.height, torus=True)
        self.datacollector = DataCollector(
            model_reporters={"Sheep": lambda m: self.schedule_Sheep.get_agent_count(),
            "Wolves": lambda m: self.schedule_Wolf.get_agent_count()},
            agent_reporters={"Eaten Sheep": 'eaten_sheep'})

        # Create sheep and wolves
        self.init_population(Sheep, self.initial_sheep)
        self.init_population(Wolf, self.initial_wolves)

        # This is required for the datacollector to work
        self.running = True
        self.datacollector.collect(self)

    def init_population(self, agent_type, n):
        '''
        Method that provides an easy way of making a bunch of agents at once.
        '''
        for i in range(n):
            x = random.randrange(self.width)
            y = random.randrange(self.height)

            self.new_agent(agent_type, (x, y))

    def new_agent(self, agent_type, pos):
        '''
        Method that creates a new agent, and adds it to the correct scheduler.
        '''
        agent = agent_type(self.next_id(), self, pos)

        self.grid.place_agent(agent, pos)
        getattr(self, f'schedule_{agent_type.__name__}').add(agent)

    def remove_agent(self, agent):
        '''
        Method that removes an agent from the grid and the correct scheduler.
        '''
        self.grid.remove_agent(agent)
        getattr(self, f'schedule_{type(agent).__name__}').remove(agent)

    def step(self):
        '''
        Method that calls the step method for each of the sheep, and then for each of the wolves.
        '''
        self.schedule_Sheep.step()
        self.schedule_Wolf.step()

        # Save the statistics
        self.datacollector.collect(self)

    def run_model(self, step_count=200):
        '''
        Method that runs the model for a specific amount of steps.
        '''
        for i in range(step_count):
            self.step()

# %% [markdown]
# You might have noticed that we are using a so called `MultiGrid`. Again, [Mesa provides us with multiple different types of environments](https://mesa.readthedocs.io/en/latest/tutorials/intro_tutorial.html#adding-space) for the agents to exist in:
# - `ContinuousSpace`: Each agent can have an arbitrary position.
# - `SingleGrid`: Grid where each cell contains at most one object.
# - `MultiGrid`: Grid where each cell can contain more than one object.
# - `HexGrid`: extends the grid to handle hexagonal neighbors.
# - `NetworkGrid`: Network where each node contains zero or more agents.
#
# We are using `MultiGrid` as we want multiple agents to be able to be in one cell.
#
# Running the model is now as simple as:

# %%
model = WolfSheep()
model.run_model()
# Out:
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (14, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (13, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (13, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (14, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (15, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (16, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (9, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (7, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (11, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (9, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (8, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (8, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (12, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (7, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (4, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (19, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (17, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (12, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (11, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (8, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (9, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (14, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (13, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (15, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (11, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (13, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (14, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (16, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (16, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (10, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (11, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (19, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (4, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (13, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (11, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (17, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (18, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (7, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (19, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (15, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (15, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (12, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (7, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (10, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (8, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (12, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (11, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (16, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (13, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (12, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (12, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (4, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (10, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (19, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (19, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (7, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (13, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (17, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (13, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (17, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (14, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (17, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (8, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (15, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (11, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (9, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (13, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (12, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (10, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (10, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (7, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (16, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (17, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (13, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (18, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (11, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (10, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (10, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (17, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 152 is being placed with
# place_agent() despite already having the position (12, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 153 is being placed with
# place_agent() despite already having the position (17, 5). In most
# ...
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 197 is being placed with
# place_agent() despite already having the position (9, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 198 is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 199 is being placed with
# place_agent() despite already having the position (18, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 200 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 201 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 202 is being placed with
# place_agent() despite already having the position (9, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 203 is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 204 is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 205 is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 206 is being placed with
# place_agent() despite already having the position (12, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 207 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 208 is being placed with
# place_agent() despite already having the position (11, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 209 is being placed with
# place_agent() despite already having the position (7, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 210 is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 211 is being placed with
# place_agent() despite already having the position (13, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 212 is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 213 is being placed with
# place_agent() despite already having the position (10, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 214 is being placed with
# place_agent() despite already having the position (19, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 215 is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 216 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 217 is being placed with
# place_agent() despite already having the position (19, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 218 is being placed with
# place_agent() despite already having the position (15, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 219 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 220 is being placed with
# place_agent() despite already having the position (16, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 221 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 222 is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 223 is being placed with
# place_agent() despite already having the position (8, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 224 is being placed with
# place_agent() despite already having the position (12, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 225 is being placed with
# place_agent() despite already having the position (12, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 226 is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 227 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 228 is being placed with
# place_agent() despite already having the position (14, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 229 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 230 is being placed with
# place_agent() despite already having the position (16, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 231 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 232 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 233 is being placed with
# place_agent() despite already having the position (15, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 234 is being placed with
# place_agent() despite already having the position (8, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 235 is being placed with
# place_agent() despite already having the position (14, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 236 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 237 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 238 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 239 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 240 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 241 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 242 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 243 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 244 is being placed with
# place_agent() despite already having the position (14, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 245 is being placed with
# place_agent() despite already having the position (11, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 246 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)

# %% [markdown]
# ### Data collector
# So far, we have tested the model by checking variables manually. This is not very efficient, and requires us to make complicated loops if we need more than just the end results. Mesa provides a class which can handle the data collection and storage. This class was already added to the model above; `DataCollector`. From the Mesa docs:
#
# "The data collector stores three categories of data: model-level variables, agent-level variables, and tables (which are a catch-all for everything else). Model- and agent-level variables are added to the data collector along with either the name of an attribute that the agents or models have, or a function for collecting some data. Model-level collection functions take a model object as an input, while agent-level collection functions take an agent object as an input. Both then return a value computed from the model or each agent at their current state. When the data collector’s collect method is called, with a model object as its argument, it applies each model-level collection function to the model, and stores the results in a dictionary, associating the current value with the current step of the model. Similarly, the method applies each agent-level collection function to each agent currently in the schedule, associating the resulting value with the step of the model, and the agent’s unique_id."
#
# Simply said, the `DataCollector` adds data to its dictionary when you call `collect()` method. We have added two functions that keep track of the amount of Sheep and Wolf to the `DataCollector` and call collect after each `step()` that the model makes.
#
# Run the following piece of code to see what happens.

# %%
# %matplotlib inline
    
model = WolfSheep()
model.run_model()

data = model.datacollector.get_model_vars_dataframe()
data.plot()
# Out:
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (7, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (13, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (16, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (6, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (16, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (14, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (8, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (10, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (19, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (11, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (11, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (13, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (8, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (12, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (18, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (14, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (7, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (16, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (16, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (14, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (10, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (13, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (18, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (9, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (13, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (11, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (10, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (19, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (14, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (13, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (8, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (8, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (16, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (8, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (14, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (12, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (11, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (7, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (12, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (7, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (16, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (11, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (13, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (8, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (7, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (10, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (7, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (9, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (16, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (12, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (14, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (12, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (19, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (10, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (7, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (12, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (7, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (12, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (4, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (11, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (14, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 152 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 153 is being placed with
# place_agent() despite already having the position (15, 18). In most
# ...
# place_agent() despite already having the position (14, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 201 is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 202 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 203 is being placed with
# place_agent() despite already having the position (11, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 204 is being placed with
# place_agent() despite already having the position (16, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 205 is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 206 is being placed with
# place_agent() despite already having the position (12, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 207 is being placed with
# place_agent() despite already having the position (17, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 208 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 209 is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 210 is being placed with
# place_agent() despite already having the position (14, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 211 is being placed with
# place_agent() despite already having the position (8, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 212 is being placed with
# place_agent() despite already having the position (11, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 213 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 214 is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 215 is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 216 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 217 is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 218 is being placed with
# place_agent() despite already having the position (15, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 219 is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 220 is being placed with
# place_agent() despite already having the position (14, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 221 is being placed with
# place_agent() despite already having the position (13, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 222 is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 223 is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 224 is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 225 is being placed with
# place_agent() despite already having the position (18, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 226 is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 227 is being placed with
# place_agent() despite already having the position (9, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 228 is being placed with
# place_agent() despite already having the position (16, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 229 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 230 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 231 is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 232 is being placed with
# place_agent() despite already having the position (17, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 233 is being placed with
# place_agent() despite already having the position (12, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 234 is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 235 is being placed with
# place_agent() despite already having the position (13, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 236 is being placed with
# place_agent() despite already having the position (16, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 237 is being placed with
# place_agent() despite already having the position (11, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 238 is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 239 is being placed with
# place_agent() despite already having the position (16, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 240 is being placed with
# place_agent() despite already having the position (19, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 241 is being placed with
# place_agent() despite already having the position (6, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 242 is being placed with
# place_agent() despite already having the position (17, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 243 is being placed with
# place_agent() despite already having the position (12, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 244 is being placed with
# place_agent() despite already having the position (7, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 245 is being placed with
# place_agent() despite already having the position (7, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 246 is being placed with
# place_agent() despite already having the position (10, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 247 is being placed with
# place_agent() despite already having the position (13, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 248 is being placed with
# place_agent() despite already having the position (8, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 249 is being placed with
# place_agent() despite already having the position (14, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\mihbo\AppData\Local\Temp\ipykernel_11408\4201063837.py:60: UserWarning: Agent 250 is being placed with
# place_agent() despite already having the position (13, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# <Axes: >

# %% [markdown]
# See if you can make a similar plot which displays the average number of sheep a wolf has eaten over its lifetime for each `step()` in the model. You will need to change the `step()` method of the wolf so that it counts every sheep it has eaten, and you will need to change the `DataCollector` to log this data. You can then use `model.datacollector.get_agent_vars_dataframe()` to get your data.
#
# Take a look at the [Mesa Read The Docs](https://mesa.readthedocs.io/en/latest/tutorials/intro_tutorial.html#collecting-data) for more details.

# %%
# Get agent data
data = model.datacollector.get_agent_vars_dataframe()

# Take average eaten sheep per step
average_eaten_sheep_per_step = data['Eaten Sheep'].groupby('Step').mean()
average_eaten_sheep_per_step.plot()
# Out:
# <Axes: xlabel='Step'>

# %% [markdown]
# ### Visualisation
# Mesa provides you with an interactive visualisation toolkit. This is done through a local server that uses JavaScript to draw  everything in a browser window. An advantage of this is that we can run models step by step, spotting patterns, behaviors, bugs, developing new intuitions, hypotheses or insights. It is also a very good way to explain a model to your roommates or grandparents.
#
# We have provided you with a seperate `server.py` that shows you how you could visualise this model, as the visualisation will not cooperate with notebooks. Feel free to take a look and change elements to get accustomed to how the visualisation module works. For more information, visit [this link](https://mesa.readthedocs.io/en/latest/tutorials/visualization_tutorial.html#building-your-own-visualization-component).
#
# Run this model by issuing the following command in the command line (in your 1-mesa folder):
#
# `> ipython server.py`
#
# NOTE: Keep in mind that the "Frames Per Second" setting does not take into account the time it takes to build a frame. This means that when your simulation takes more time to build a frame than it takes the visualisation to display it, and you press stop, the visualisation will continue untill it has displayed all the frames that it should have displayed in the first place. To prevent this from happening, do not set "Frames Per Second" too high.

# %% [markdown]
# ### Mesa best practices
# To ensure that our models are easily accessible and maintainable, Mesa provides us with some general principles. These principles can be found [here](https://mesa.readthedocs.io/en/latest/best-practices.html), but the main take-away is that you should structure your files. The model class for example, should be located in `model.py` and generally, the agents should be located in `agent.py`.
