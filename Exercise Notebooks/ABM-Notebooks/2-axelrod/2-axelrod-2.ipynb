# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "BoyanMihaylov"

# %% [markdown]
# # Game theory in Python
#
# In this notebook we reiterate the topics touched in the lecture, get used to the basic concepts of game theory, as well as how to implement it using Python. The notebook contains four parts:
# - The (iterated) prisonners dilemma,
# - Evolutionary hawk-dove game,
# - Calculating Nash equilibria,
# - Calculating dominant strategies.
#
# First we install the package axelrod and test if we can import it.

# %%
from IPython.display import clear_output
import axelrod
import numpy as np
clear_output()
print("Everything imported!")
# Out:
# Everything imported!

# %% [markdown]
# ### Effective Choice in the Prisoners Dilemma
# In the first part of the notebook we will recreate the research originally done by Axelrod. Start with reading his [paper](./AxelrodEffectiveChoiceinthePrisonersDilemma.pdf) (Its the pdf in the same folder as the notebook, open it outside notebook environment)
# .
#
# Fortunately for us, the prisoners dilemma is already implemented as a Python package, called Axelrod. Take a look at their [GitHub page](https://github.com/Axelrod-Python/Axelrod) and their [readthedocs](https://axelrod.readthedocs.io/en/stable/).
#
# <table>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Player B</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>C</td>
#         <td>D</td>
#     </tr>
#     <tr>
#         <td>Player A</td>
#         <td>C</td>
#         <td>(3, 3)</td>
#         <td>(0, 5)</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>D</td>
#         <td>(5, 0)</td>
#         <td>(1, 1)</td>
#     </tr>
# </table>
#
#
# To get used to the workflow of axelrod we begin by implementing a simple match. In this match we will want to see the result of a prisonners dilemma between a so-called cooperator strategy, and a so-called alternator strategy. We already implemented this for you:

# %%
import axelrod as axl
# make a tuple, called players, containing Cooperator and an Alternator
players = (axl.Cooperator(), axl.Alternator())

# let them play
match = axl.Match(players, turns=5)
turns = match.play()

# extract the final_score and winner from the match
final_score = match.final_score()
winner = match.winner()

print(f'turns: \t\t{turns}')
print(f'final_score: \t{final_score}')
print(f'winner: \t{winner}')
# Out:
# turns: 		[(C, C), (C, D), (C, C), (C, D), (C, C)]
# final_score: 	(9, 19)
# winner: 	Alternator

# %% [markdown]
# Axelrod 'organised' a tournament with many players. Here we will recreate the (first) tournament with axelrod. Take a look at [which strategies of the (first) tournament are implemented in axelrod](https://axelrod.readthedocs.io/en/stable/discussion/overview_of_past_tournaments.html#axelrod-s-first-tournament), and take a look [how to implement a tournament](https://axelrod.readthedocs.io/en/stable/tutorials/new_to_game_theory_and_or_python/index.html).

# %%
# Collect all the strategies played at the first tournament
strategies = [strategy() for strategy in axl.axelrod_first_strategies]
print(strategies)

tournament = axl.Tournament(strategies, 
                            turns=200,
                            repetitions=10)


results = tournament.play()
plot = axl.Plot(results)

plot.boxplot();
plot.payoff();
# Out:
# [Tit For Tat, First by Tideman and Chieruzzi: (D, D), First by Nydegger, First by Grofman, First by Shubik, First by Stein and Rapoport: 0.05: (D, D), Grudger, First by Davis: 10, First by Graaskamp: 0.05, First by Downing, First by Feld: 1.0, 0.5, 200, First by Joss: 0.9, First by Tullock, First by Anonymous, Random: 0.5]
# Playing matches: 100%|██████████| 120/120 [00:02<00:00, 41.24it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 195.07it/s]

# %% [markdown]
# Notice the similarity in strategy between the high scoring strategies? They are never the first to defect, **be nice**!

# %% [markdown]
# ### Evolutionary hawk-dove game
# The hawk-dove game is a game where two birds fight over some food, where the reward of the food is V. If both birds decide to be unagressive (dove), they each get half of the food. If one of the birds decides for fight for the food (hawk), while the other bird is unaggresive, the hawk gets all the food. If both birds are aggresive, they each get half the food minus the cost (C) of fighting:
#
# <table>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Player B</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Dove</td>
#         <td>Hawk</td>
#     </tr>
#     <tr>
#         <td>Player A</td>
#         <td>Dove</td>
#         <td>(V/2, V/2)</td>
#         <td>(0, V)</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>Hawk</td>
#         <td>(V, 0)</td>
#         <td>((V-C) / 2, (V-C) / 2)</td>
#     </tr>
# </table>
#
# In this assignment we will implement an evolutionary hawk-dove game, as well as calculate the expected payoff for each strategy.
#
# $$
# \begin{cases}
# (V - C) / 2 > 0 & \text{Hawk strategy dominant}\\
# (V - C) / 2 < 0 & \text{Mixed strategy!}
# \end{cases}
# $$
#
# For a mixed strategy to hold the expected payoff for Hawk must be equal to Dove:
# $$
# E(U_D) = E(U_H)
# $$
#
# The expected payoff for dove:
# $$
# E(U_D) = \frac{V}{2}(1 - p_H)
# $$
#
# The expected payoff for hawk:
# $$
# E(U_H) = \frac{V - C}{2}p_H + V (1-p_H)
# $$
#
# Now solve:
# $$
# \frac{V}{2}(1 - p_H) = \frac{V - C}{2}p_H + V (1-p_H) \\
# $$
# And implement function proportion_hawk, that calculates the proportion of hawks, $p_H$, according to this equation.

# %% [markdown]
# Expanding and rewriting the equation above:
#
# $$
# \frac{V}{2}-\frac{V}{2}p_H=\frac{V}{2}p_H-\frac{C}{2}p_H+V-Vp_H
# $$
#
# $$
# Vp_H-\frac{V}{2}p_H-\frac{V}{2}p_H+\frac{C}{2}p_H=V-\frac{V}{2}
# $$
#
# $$
# p_H = \frac{V}{C}
# $$

# %%
def proportion_hawk(V, C):
    """
    This function returns the expected number of hawks for V and C.
    """
    
    prop_hawk = V / C
    prop_hawk = np.clip(prop_hawk, 0, 1)

    return prop_hawk

# %%
assert isinstance(proportion_hawk(1, 2), (int, float)), "The function should return numerical (int of float) values"
assert 0 <= proportion_hawk(1, 2) <= 1, "A proportion value is always between 0 and 1!"
assert proportion_hawk(2, 1) == 1, "This is a hawk-dominant solution!"

# %% [markdown]
# We can test if our calculation is correct/holds in an evolutionary setting. We will test this by implementing a [Moran Process](https://axelrod.readthedocs.io/en/latest/tutorials/new_to_game_theory_and_or_python/moran.html), which is an evolutionary game, where after each round in the tournament one random individual changes its strategy based on fitness proportionate selection. Implement your  [new game](https://axelrod.readthedocs.io/en/stable/how-to/use_different_stage_games.html) based on the hawk-dove payoff, and feed it to a Moran process.
#
# Make sure to consult the documentation of the Moran Process, to ensure you pass the correctly formated arguments.

# %%
import matplotlib.pyplot as plt

# Set the values 
V = 1
C = 3

# Generate for instance 25 hawks (defectors) and 25 (cooperators)
print(f"Hawk-dominant strategy at hawk proportion of {proportion_hawk(V, C)}.")
n_hawks = 25
n_doves = 25
players = [axl.Defector() for _ in range(n_hawks)] + [axl.Cooperator() for _ in range(n_doves)]

# Implement a hawk dove game
hawkdove = axelrod.game.Game(r=V/2, s=0, t=V, p=(V-C)/2)

# feed the hawkdove game to the MoranProcess
mp = axl.MoranProcess(players, turns=1, game=hawkdove)

# let's see how it evolves
iters = 100
for _ in range(iters):
    if not mp.fixation_check():
        next(mp)
        
# now make a pretty plot
mp.populations_plot()
plt.show()
# Out:
# Hawk-dominant strategy at hawk proportion of 0.3333333333333333.

# %%
assert "players" in vars(), "store the the strategies as variable players"
assert all(type(player).__name__ in ['Cooperator', 'Defector'] for player in players), "only hawks and doves, please!"

assert "hawkdove" in vars(), "store the hawk dove ´game' as variable hawkdove"
assert type(hawkdove).__name__ == 'Game'

# %% [markdown]
# ### Nash equilibria
# Nash equilibria are equilibria where no player has anything to **gain** by changing only their own strategy. Implement the function `find_nash()`, that returns the list of nash equilibria for a payoff matrix. We already implemented the functions max_row and max_col for you, which might help in solving the assignment.

# %%
def max_row(matrix, row_nr):
    """
    A helper function that returns the maximum payoff for player B given a row index
    """
    return max(x[0] for x in matrix[row_nr])

def max_col(matrix, col_nr):
    """
    A helper function that returns the maximum payoff for player A given a column index
    """
    return max(matrix[i][col_nr][1] for i in range(len(matrix)))
    
def find_nash(payoff_matrix):
    """
    Returns a list of indices [(index_player_B, index_player_A)] of the Nash-equilibria. 
    If no indices are present returns an empty list.
    """
    nash_equilibria = []
    
    for i in range(len(payoff_matrix)):
        for j in range(len(payoff_matrix[i])):
            if payoff_matrix[i][j][0] == max_row(payoff_matrix, i) and payoff_matrix[i][j][1] == max_col(payoff_matrix, j):
                nash_equilibria.append((i, j))

    return nash_equilibria

# %%
payoff_matrix = [[(1, 0), (0, 1)],
                 [(0, 1), (1, 0)]]
assert set(find_nash(payoff_matrix)) == set([])

payoff_matrix = [[(2, 2), (0, 0)],
                 [(0, 0), (1, 1)]]
assert set(find_nash(payoff_matrix)) == set([(0, 0), (1, 1)])

payoff_matrix = [[(0, 0), (1, 1)],
                 [(1, 1), (1, 1)]]
assert set(find_nash(payoff_matrix)) == set([(0, 1), (1, 0), (1, 1)])

payoff_matrix = [[(0, 0), (1, 1)],
                 [(1, 1), (1, 1)],
                 [(2, 2), (1, 1)]]
assert set(find_nash(payoff_matrix)) == set([(0, 1), (1, 1), (2, 0)])

# %% [markdown]
# ### Iterated Elimination of Dominated Strategies (IEDS)
# A strictly dominant strategy is a strategy that is always better than all other strategies for a player. Let's assume the following payoff table:
# <table>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Player B</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>C</td>
#         <td>**D**</td>
#     </tr>
#     <tr>
#         <td>Player A</td>
#         <td>C</td>
#         <td>(2, 1)</td>
#         <td>**(1, 4)**</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>D</td>
#         <td>(1, 2)</td>
#         <td>**(2, 3)**</td>
#     </tr>
# </table>
# For player A it is unclear whether to play Cooperate or Defect, since it depends on the strategy of the other player which is best. However, for player B it is always better to defect, since those rewards are always higher than the cooperation scores. We say that Cooperation is a (strictly) dominated rule, we can therefore ignore this row in the game (under the assumption that the player is purely rational):
# <table>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Player B</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>D</td>
#     </tr>
#     <tr>
#         <td>Player A</td>
#         <td>C</td>
#         <td></td>
#         <td>(1, 4)</td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>**D**</td>
#         <td></td>
#         <td>**(2, 3)**</td>
#     </tr>
# </table>
# Since player A knows the payoff for player B, it knows that player B will always play Defect. Using this knowledge, it is obvious for player A that Defection always has a higher reward than Cooperation (Cooperation is dominated by Defect). We can therefore also ignore the Cooperation column for player A. Now we end up with a simple table with one **dominant** option:
# <table>
#     <tr>
#         <td></td>
#         <td></td>
#         <td>Player B</td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>D</td>
#     </tr>
#     <tr>
#         <td>Player A</td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td></td>
#         <td>D</td>
#         <td></td>
#         <td>(2, 3)</td>
#     </tr>
# </table>
# Rational players will always always play defect with the original payoff matrix.
#
# In the next assignment we will implement the Iterated Elimination of Dominated Strategies algorithm (only pure strategies). The algorithm works by iteratively removing dominated strategies, just like we did in the example. You only have to remove **strictly dominated** strategies! We already implemented the functions `remove_row()` and `remove_col()` for you, which might help in solving the assignment.

# %%
import copy

def remove_row(matrix, row_nr):
    """
    A helper function that deletes a row by its index
    """
    del matrix[row_nr]
    
def remove_col(matrix, col_nr):
    """
    A helper function that deletes a column by its index
    """
    for row_i in range(len(matrix)):
        del matrix[row_i][col_nr]


def IEDS(payoff_matrix):
    """
    The Iterated Elimination of Dominated Strategies algorithm. 
    Returns the smallest subset of non-dominated strategies
    """
    matrix = copy.deepcopy(payoff_matrix)
    
    # iterate until no more dominated strategies are found
    for n in range(len(matrix) * len(matrix[0])):
        
        # remove dominated rows
        for i in range(len(matrix)):
            skip = False
            for j in range(len(matrix)):
                if i != j and all(matrix[i][k][0] < matrix[j][k][0] for k in range(len(matrix[i]))):
                    remove_row(matrix, i)
                    skip = True
                    break
            if skip:
                break

        # remove dominated columns
        for i in range(len(matrix[0])):
            skip = False
            for j in range(len(matrix[0])):
                if i != j and all(matrix[k][i][1] < matrix[k][j][1] for k in range(len(matrix))):
                    remove_col(matrix, i)
                    skip = True
                    break
            if skip:
                break
    
    return matrix

# %%
payoff_matrix = [[(1, 1)]]
assert IEDS(payoff_matrix) == [[(1, 1)]]

payoff_matrix = [[(2, 2)],
                 [(1, 1)],
                 [(7, 1)],
                 [(1, 2)]]
assert IEDS(payoff_matrix) == [[(7, 1)]]

payoff_matrix = [[(2, 2), (1, 1)],
                 [(1, 1), (0, 0)]]
assert IEDS(payoff_matrix) == [[(2, 2)]]

payoff_matrix = [[(3, 1), (0, 1), (0, 0)],
                 [(1, 1), (1, 1), (5, 0)],
                 [(0, 1), (4, 1), (0, 0)]]
assert IEDS(payoff_matrix) == [[(3, 1), (0, 1)], 
                               [(1, 1), (1, 1)], 
                               [(0, 1), (4, 1)]]

# %% [markdown]
# ### Bonus: Spatial prisonners dilemma
# The module axelrod has a built-in option for spatial tournaments, see [here](https://axelrod.readthedocs.io/en/stable/how-to/create_spatial_tournaments.html). Or you could easily combine it with mesa! Take a look at the folder mesa_axelrod for a very simple example, where there are agents walking around randomly, and playing iterated prisonners dilemma. Winners reproduce, and losers die.

# %%
import sys
sys.path.append('mesa_axelrod')

from axelrod_mesa import MesaAxelrod

maxl = MesaAxelrod()
maxl.run_model()
# Out:
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (16, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (14, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (13, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (11, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (15, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (9, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (17, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (18, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (18, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (10, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (17, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (12, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (9, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (10, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (15, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (14, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (19, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (10, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (14, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (7, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (8, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (7, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (17, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (13, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (18, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (18, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (10, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (11, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (8, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (10, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (8, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (13, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (8, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (8, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (17, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (15, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (4, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (17, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (11, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (17, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (17, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (13, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (12, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (12, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (13, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:37: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (17, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 7
#       4 from axelrod_mesa import MesaAxelrod
#       6 maxl = MesaAxelrod()
# ----> 7 maxl.run_model()
#
# File d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:64, in MesaAxelrod.run_model(self, step_count)
#      60 """
#      61 Method that runs the model for a specific amount of steps.
#      62 """
#      63 for i in range(step_count):
# ---> 64     self.step()
#
# File d:\MSc Computational Science\S02P03\Agent Based Modelling\GitHub\agent-based-modelling\Exercise Notebooks\ABM-Notebooks\2-axelrod\mesa_axelrod\axelrod_mesa.py:54, in MesaAxelrod.step(self)
#      48 """
#      49 step through all agents and step()
#      50 self-implemented scheduler that allows removal of agents during stepping
#      51 """
#      52 agents = self.scheduler._agents
# ---> 54 agent_keys = list(agents.keys())
#      55 for key in agent_keys:
#      56     if key in agents:
#
# AttributeError: 'AgentSet' object has no attribute 'keys'
