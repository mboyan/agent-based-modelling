# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x0 = 1

t_max = 120

xs = np.zeros(t_max)
ys = np.zeros(t_max)

for t in range(t_max):
    x0 = x0 * np.exp(1.03 * (1 - x0 / 350) ** 6)
    xs[t] = t
    ys[t] = x0
plt.plot(xs, ys)

print(np.mean(ys))

x0
# Out:
# 206.5057125862784
# 242.83926758418622
